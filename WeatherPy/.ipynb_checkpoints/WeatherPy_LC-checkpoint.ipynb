# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# %%
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Results/Cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %%
cities[0]
# Out:
# 'hobart'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Test API call to check response
base_url= "http://api.openweathermap.org/data/2.5/weather?"
city_id=1

city="hobart"
query_url= base_url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
response=requests.get(query_url).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1586881783,
#  'id': 2163355,
#  'main': {'feels_like': 12.89,
#           'humidity': 77,
#           'pressure': 1018,
#           'temp': 13.91,
#           'temp_max': 15.56,
#           'temp_min': 11.11},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'sunrise': 1586896963,
#          'sunset': 1586936297,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 1.5}}

# %%
#Create empty dataframe to populate with retrieved info
cities_df=pd.DataFrame({
    "City Number":[],
    "City":[],
    "Cloudiness":[],
    "Date":[],
    "Humidity":[],
    "Lat":[],
    "Lng":[],
    "Max Temp":[],
    "Wind Speed":[]
})
cities_df.head()
# Out:
# Empty DataFrame
# Columns: [City Number, City, Cloudiness, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
#API calls for each city in cities
base_url= "http://api.openweathermap.org/data/2.5/weather?"
city_id=1
index=0

for city in cities:
    try:
        query_url= base_url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
        response=requests.get(query_url).json()
        print(f'Retrieving Weather for city number:{city_id} | {city}')
        cities_df.loc[index, "City Number"]=int(city_id)
        cities_df.loc[index, "City"]=response["name"]
        cities_df.loc[index, "Cloudiness"]=response["clouds"]["all"]
        cities_df.loc[index, "Date"]=response["dt"]
        cities_df.loc[index, "Humidity"]=response["main"]["humidity"]
        cities_df.loc[index, "Lat"]=response["coord"]["lat"]
        cities_df.loc[index, "Lng"]=response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]=response["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"]=response["wind"]["speed"]
        index+=1
        city_id+=1
    except(KeyError, IndexError):
        print("City not found. Skipping")
# Out:
# Retrieving Weather for city number:1 | hobart
# Retrieving Weather for city number:2 | punta arenas
# Retrieving Weather for city number:3 | kurumkan
# Retrieving Weather for city number:4 | temerloh
# Retrieving Weather for city number:5 | castro
# Retrieving Weather for city number:6 | ribeira grande
# Retrieving Weather for city number:7 | saint-joseph
# Retrieving Weather for city number:8 | bell ville
# Retrieving Weather for city number:9 | ushuaia
# Retrieving Weather for city number:10 | mahadday weyne
# City not found. Skipping
# Retrieving Weather for city number:10 | taolanaro
# City not found. Skipping
# Retrieving Weather for city number:10 | caborca
# Retrieving Weather for city number:11 | bengkulu
# Retrieving Weather for city number:12 | saint george
# Retrieving Weather for city number:13 | kavaratti
# Retrieving Weather for city number:14 | tuktoyaktuk
# Retrieving Weather for city number:15 | samalaeulu
# City not found. Skipping
# Retrieving Weather for city number:15 | hithadhoo
# Retrieving Weather for city number:16 | ternate
# Retrieving Weather for city number:17 | pirenopolis
# Retrieving Weather for city number:18 | lavrentiya
# Retrieving Weather for city number:19 | tsihombe
# City not found. Skipping
# Retrieving Weather for city number:19 | rawson
# Retrieving Weather for city number:20 | pevek
# Retrieving Weather for city number:21 | lorengau
# Retrieving Weather for city number:22 | hilo
# Retrieving Weather for city number:23 | lugo
# Retrieving Weather for city number:24 | saint-philippe
# Retrieving Weather for city number:25 | rikitea
# Retrieving Weather for city number:26 | coelho neto
# Retrieving Weather for city number:27 | carnarvon
# Retrieving Weather for city number:28 | longyearbyen
# Retrieving Weather for city number:29 | gasa
# Retrieving Weather for city number:30 | aklavik
# Retrieving Weather for city number:31 | scarborough
# Retrieving Weather for city number:32 | barrow
# Retrieving Weather for city number:33 | atuona
# Retrieving Weather for city number:34 | coahuayana
# Retrieving Weather for city number:35 | kapaa
# Retrieving Weather for city number:36 | kamaishi
# Retrieving Weather for city number:37 | mataura
# Retrieving Weather for city number:38 | ilulissat
# Retrieving Weather for city number:39 | busselton
# Retrieving Weather for city number:40 | bredasdorp
# Retrieving Weather for city number:41 | nouadhibou
# Retrieving Weather for city number:42 | ponta do sol
# Retrieving Weather for city number:43 | praia da vitoria
# Retrieving Weather for city number:44 | srednekolymsk
# Retrieving Weather for city number:45 | cherskiy
# Retrieving Weather for city number:46 | marystown
# Retrieving Weather for city number:47 | nosy varika
# Retrieving Weather for city number:48 | narsaq
# Retrieving Weather for city number:49 | umzimvubu
# City not found. Skipping
# Retrieving Weather for city number:49 | port hueneme
# Retrieving Weather for city number:50 | batemans bay
# Retrieving Weather for city number:51 | mahebourg
# Retrieving Weather for city number:52 | bangassou
# Retrieving Weather for city number:53 | kaitangata
# Retrieving Weather for city number:54 | sahrak
# City not found. Skipping
# Retrieving Weather for city number:54 | spassk-ryazanskiy
# Retrieving Weather for city number:55 | saint-augustin
# Retrieving Weather for city number:56 | cape town
# Retrieving Weather for city number:57 | nelson bay
# Retrieving Weather for city number:58 | torbay
# Retrieving Weather for city number:59 | togur
# Retrieving Weather for city number:60 | salinopolis
# Retrieving Weather for city number:61 | hobyo
# Retrieving Weather for city number:62 | dong hoi
# Retrieving Weather for city number:63 | vaini
# Retrieving Weather for city number:64 | souillac
# Retrieving Weather for city number:65 | georgetown
# Retrieving Weather for city number:66 | ardistan
# City not found. Skipping
# Retrieving Weather for city number:66 | avarua
# Retrieving Weather for city number:67 | itaituba
# Retrieving Weather for city number:68 | butaritari
# Retrieving Weather for city number:69 | maragogi
# Retrieving Weather for city number:70 | maunabo
# Retrieving Weather for city number:71 | rio gallegos
# Retrieving Weather for city number:72 | kamyshevatskaya
# Retrieving Weather for city number:73 | tuatapere
# Retrieving Weather for city number:74 | saleaula
# City not found. Skipping
# Retrieving Weather for city number:74 | port hardy
# Retrieving Weather for city number:75 | buchanan
# Retrieving Weather for city number:76 | emerald
# Retrieving Weather for city number:77 | okha
# Retrieving Weather for city number:78 | illoqqortoormiut
# City not found. Skipping
# Retrieving Weather for city number:78 | puerto ayora
# Retrieving Weather for city number:79 | haverfordwest
# Retrieving Weather for city number:80 | phayuha khiri
# Retrieving Weather for city number:81 | lebu
# Retrieving Weather for city number:82 | albany
# Retrieving Weather for city number:83 | hermanus
# Retrieving Weather for city number:84 | chuy
# Retrieving Weather for city number:85 | muros
# Retrieving Weather for city number:86 | haines junction
# Retrieving Weather for city number:87 | uray
# Retrieving Weather for city number:88 | faya
# Retrieving Weather for city number:89 | tagusao
# Retrieving Weather for city number:90 | ippy
# Retrieving Weather for city number:91 | hofn
# Retrieving Weather for city number:92 | tasiilaq
# Retrieving Weather for city number:93 | banda aceh
# Retrieving Weather for city number:94 | bluff
# Retrieving Weather for city number:95 | nikolskoye
# Retrieving Weather for city number:96 | candido de abreu
# Retrieving Weather for city number:97 | hericourt
# Retrieving Weather for city number:98 | perivolion
# Retrieving Weather for city number:99 | iqaluit
# Retrieving Weather for city number:100 | fortuna
# Retrieving Weather for city number:101 | beckley
# Retrieving Weather for city number:102 | belushya guba
# City not found. Skipping
# Retrieving Weather for city number:102 | beidao
# Retrieving Weather for city number:103 | grand gaube
# Retrieving Weather for city number:104 | prince george
# Retrieving Weather for city number:105 | arman
# Retrieving Weather for city number:106 | grindavik
# Retrieving Weather for city number:107 | pailon
# Retrieving Weather for city number:108 | bollnas
# Retrieving Weather for city number:109 | ruteng
# Retrieving Weather for city number:110 | nouna
# Retrieving Weather for city number:111 | lesosibirsk
# Retrieving Weather for city number:112 | port alfred
# Retrieving Weather for city number:113 | minna
# Retrieving Weather for city number:114 | kruisfontein
# Retrieving Weather for city number:115 | pouebo
# Retrieving Weather for city number:116 | namibe
# Retrieving Weather for city number:117 | port elizabeth
# Retrieving Weather for city number:118 | lima
# Retrieving Weather for city number:119 | mount isa
# Retrieving Weather for city number:120 | jamestown
# Retrieving Weather for city number:121 | taoudenni
# Retrieving Weather for city number:122 | sao filipe
# Retrieving Weather for city number:123 | villaviciosa
# Retrieving Weather for city number:124 | kodiak
# Retrieving Weather for city number:125 | tateyama
# Retrieving Weather for city number:126 | milkovo
# Retrieving Weather for city number:127 | palmer
# Retrieving Weather for city number:128 | bend
# Retrieving Weather for city number:129 | katsuura
# Retrieving Weather for city number:130 | wahpeton
# Retrieving Weather for city number:131 | kayerkan
# Retrieving Weather for city number:132 | lompoc
# Retrieving Weather for city number:133 | sabang
# Retrieving Weather for city number:134 | bethel
# Retrieving Weather for city number:135 | kroya
# Retrieving Weather for city number:136 | sao joao da barra
# Retrieving Weather for city number:137 | sao joaquim
# Retrieving Weather for city number:138 | lityn
# Retrieving Weather for city number:139 | seminole
# Retrieving Weather for city number:140 | barahona
# Retrieving Weather for city number:141 | pudozh
# Retrieving Weather for city number:142 | willowmore
# Retrieving Weather for city number:143 | esperance
# Retrieving Weather for city number:144 | mendi
# Retrieving Weather for city number:145 | mar del plata
# Retrieving Weather for city number:146 | dingle
# Retrieving Weather for city number:147 | upernavik
# Retrieving Weather for city number:148 | agva
# City not found. Skipping
# Retrieving Weather for city number:148 | mata
# Retrieving Weather for city number:149 | nanortalik
# Retrieving Weather for city number:150 | norman wells
# Retrieving Weather for city number:151 | konya
# Retrieving Weather for city number:152 | coihueco
# Retrieving Weather for city number:153 | piryion
# City not found. Skipping
# Retrieving Weather for city number:153 | hasaki
# Retrieving Weather for city number:154 | sechura
# Retrieving Weather for city number:155 | arraial do cabo
# Retrieving Weather for city number:156 | saskylakh
# Retrieving Weather for city number:157 | chokurdakh
# Retrieving Weather for city number:158 | provideniya
# Retrieving Weather for city number:159 | tikrit
# Retrieving Weather for city number:160 | camocim
# Retrieving Weather for city number:161 | hami
# Retrieving Weather for city number:162 | vaitupu
# City not found. Skipping
# Retrieving Weather for city number:162 | olafsvik
# Retrieving Weather for city number:163 | klaksvik
# Retrieving Weather for city number:164 | new norfolk
# Retrieving Weather for city number:165 | naze
# Retrieving Weather for city number:166 | cidreira
# Retrieving Weather for city number:167 | betsiamites
# Retrieving Weather for city number:168 | yakeshi
# Retrieving Weather for city number:169 | sentyabrskiy
# City not found. Skipping
# Retrieving Weather for city number:169 | utete
# Retrieving Weather for city number:170 | vila velha
# Retrieving Weather for city number:171 | tsabong
# Retrieving Weather for city number:172 | poum
# Retrieving Weather for city number:173 | pangody
# Retrieving Weather for city number:174 | leningradskiy
# Retrieving Weather for city number:175 | pangnirtung
# Retrieving Weather for city number:176 | nabannagan
# Retrieving Weather for city number:177 | moses lake
# Retrieving Weather for city number:178 | prince rupert
# Retrieving Weather for city number:179 | cuauhtemoc
# Retrieving Weather for city number:180 | candawaga
# City not found. Skipping
# Retrieving Weather for city number:180 | mocambique
# City not found. Skipping
# Retrieving Weather for city number:180 | beringovskiy
# Retrieving Weather for city number:181 | lampa
# Retrieving Weather for city number:182 | sao miguel do oeste
# City not found. Skipping
# Retrieving Weather for city number:182 | amderma
# City not found. Skipping
# Retrieving Weather for city number:182 | fort-shevchenko
# Retrieving Weather for city number:183 | winslow
# Retrieving Weather for city number:184 | faanui
# Retrieving Weather for city number:185 | egvekinot
# Retrieving Weather for city number:186 | sorland
# Retrieving Weather for city number:187 | jalu
# Retrieving Weather for city number:188 | peniche
# Retrieving Weather for city number:189 | suntar
# Retrieving Weather for city number:190 | rongcheng
# Retrieving Weather for city number:191 | bonavista
# Retrieving Weather for city number:192 | kilis
# Retrieving Weather for city number:193 | ugoofaaru
# Retrieving Weather for city number:194 | moerai
# Retrieving Weather for city number:195 | hambantota
# Retrieving Weather for city number:196 | agdam
# Retrieving Weather for city number:197 | byron bay
# Retrieving Weather for city number:198 | serebryansk
# Retrieving Weather for city number:199 | anton lizardo
# Retrieving Weather for city number:200 | los corrales de buelna
# Retrieving Weather for city number:201 | airai
# Retrieving Weather for city number:202 | namatanai
# Retrieving Weather for city number:203 | jinchengjiang
# City not found. Skipping
# Retrieving Weather for city number:203 | polczyn-zdroj
# Retrieving Weather for city number:204 | temaraia
# City not found. Skipping
# Retrieving Weather for city number:204 | graaff-reinet
# Retrieving Weather for city number:205 | severo-kurilsk
# Retrieving Weather for city number:206 | evensk
# Retrieving Weather for city number:207 | yellowknife
# Retrieving Weather for city number:208 | borama
# City not found. Skipping
# Retrieving Weather for city number:208 | ust-kuyga
# Retrieving Weather for city number:209 | dover
# Retrieving Weather for city number:210 | adrar
# Retrieving Weather for city number:211 | ambulu
# Retrieving Weather for city number:212 | boguchany
# Retrieving Weather for city number:213 | salinas
# Retrieving Weather for city number:214 | fez
# Retrieving Weather for city number:215 | gremyachinsk
# Retrieving Weather for city number:216 | aksarka
# Retrieving Weather for city number:217 | hamilton
# Retrieving Weather for city number:218 | bukachacha
# Retrieving Weather for city number:219 | behbahan
# Retrieving Weather for city number:220 | thompson
# Retrieving Weather for city number:221 | kankan
# Retrieving Weather for city number:222 | tumannyy
# City not found. Skipping
# Retrieving Weather for city number:222 | san patricio
# Retrieving Weather for city number:223 | nizhneyansk
# City not found. Skipping
# Retrieving Weather for city number:223 | cockburn town
# Retrieving Weather for city number:224 | victoria
# Retrieving Weather for city number:225 | mount darwin
# Retrieving Weather for city number:226 | mys shmidta
# City not found. Skipping
# Retrieving Weather for city number:226 | kollam
# Retrieving Weather for city number:227 | codrington
# Retrieving Weather for city number:228 | ostrovnoy
# Retrieving Weather for city number:229 | cap malheureux
# Retrieving Weather for city number:230 | mayo
# Retrieving Weather for city number:231 | sinnamary
# Retrieving Weather for city number:232 | batagay
# Retrieving Weather for city number:233 | henties bay
# Retrieving Weather for city number:234 | melk
# Retrieving Weather for city number:235 | elko
# Retrieving Weather for city number:236 | vanimo
# Retrieving Weather for city number:237 | tawang
# Retrieving Weather for city number:238 | krasnoselkup
# Retrieving Weather for city number:239 | lolua
# City not found. Skipping
# Retrieving Weather for city number:239 | vostok
# Retrieving Weather for city number:240 | marathon
# Retrieving Weather for city number:241 | flin flon
# Retrieving Weather for city number:242 | mazatlan
# Retrieving Weather for city number:243 | camacha
# Retrieving Weather for city number:244 | puro
# Retrieving Weather for city number:245 | san ignacio
# Retrieving Weather for city number:246 | kamenskoye
# City not found. Skipping
# Retrieving Weather for city number:246 | labuhan
# Retrieving Weather for city number:247 | kosino
# Retrieving Weather for city number:248 | te anau
# Retrieving Weather for city number:249 | boo
# Retrieving Weather for city number:250 | margate
# Retrieving Weather for city number:251 | lianzhou
# Retrieving Weather for city number:252 | waw
# Retrieving Weather for city number:253 | pauini
# Retrieving Weather for city number:254 | coihaique
# Retrieving Weather for city number:255 | mandalgovi
# Retrieving Weather for city number:256 | geraldton
# Retrieving Weather for city number:257 | santa maria
# Retrieving Weather for city number:258 | elizabeth city
# Retrieving Weather for city number:259 | lahuachaca
# Retrieving Weather for city number:260 | karamea
# City not found. Skipping
# Retrieving Weather for city number:260 | cantanhede
# Retrieving Weather for city number:261 | ancud
# Retrieving Weather for city number:262 | rio pardo de minas
# Retrieving Weather for city number:263 | tadine
# Retrieving Weather for city number:264 | alofi
# Retrieving Weather for city number:265 | ukiah
# Retrieving Weather for city number:266 | scottsboro
# Retrieving Weather for city number:267 | zhigansk
# Retrieving Weather for city number:268 | tucumcari
# Retrieving Weather for city number:269 | kanbe
# Retrieving Weather for city number:270 | tarko-sale
# Retrieving Weather for city number:271 | yeniseysk
# Retrieving Weather for city number:272 | shimoda
# Retrieving Weather for city number:273 | penzance
# Retrieving Weather for city number:274 | karasjok
# Retrieving Weather for city number:275 | ust-kan
# Retrieving Weather for city number:276 | rafai
# Retrieving Weather for city number:277 | barentsburg
# City not found. Skipping
# Retrieving Weather for city number:277 | villa carlos paz
# Retrieving Weather for city number:278 | kavieng
# Retrieving Weather for city number:279 | qaanaaq
# Retrieving Weather for city number:280 | odweyne
# Retrieving Weather for city number:281 | salaga
# Retrieving Weather for city number:282 | sembe
# Retrieving Weather for city number:283 | shizunai
# Retrieving Weather for city number:284 | tunduru
# City not found. Skipping
# Retrieving Weather for city number:284 | iskateley
# Retrieving Weather for city number:285 | marcona
# City not found. Skipping
# Retrieving Weather for city number:285 | hihifo
# City not found. Skipping
# Retrieving Weather for city number:285 | waterloo
# Retrieving Weather for city number:286 | puerto baquerizo moreno
# Retrieving Weather for city number:287 | saldanha
# Retrieving Weather for city number:288 | morant bay
# Retrieving Weather for city number:289 | salalah
# Retrieving Weather for city number:290 | anderson
# Retrieving Weather for city number:291 | roros
# Retrieving Weather for city number:292 | broadford
# Retrieving Weather for city number:293 | rosarito
# Retrieving Weather for city number:294 | okhotsk
# Retrieving Weather for city number:295 | fairbanks
# Retrieving Weather for city number:296 | worland
# Retrieving Weather for city number:297 | ranong
# Retrieving Weather for city number:298 | natal
# Retrieving Weather for city number:299 | severobaykalsk
# Retrieving Weather for city number:300 | sarangani
# Retrieving Weather for city number:301 | lazaro cardenas
# Retrieving Weather for city number:302 | ingraj bazar
# Retrieving Weather for city number:303 | faranah
# Retrieving Weather for city number:304 | qena
# Retrieving Weather for city number:305 | oktyabrskoye
# Retrieving Weather for city number:306 | presidente medici
# Retrieving Weather for city number:307 | anshun
# Retrieving Weather for city number:308 | matveyevka
# Retrieving Weather for city number:309 | namie
# Retrieving Weather for city number:310 | nantucket
# Retrieving Weather for city number:311 | southbridge
# Retrieving Weather for city number:312 | rondonopolis
# Retrieving Weather for city number:313 | fare
# Retrieving Weather for city number:314 | nueva concepcion
# Retrieving Weather for city number:315 | banjar
# Retrieving Weather for city number:316 | tabou
# Retrieving Weather for city number:317 | samusu
# City not found. Skipping
# Retrieving Weather for city number:317 | greenville
# Retrieving Weather for city number:318 | naifaru
# Retrieving Weather for city number:319 | talnakh
# Retrieving Weather for city number:320 | tura
# Retrieving Weather for city number:321 | opuwo
# Retrieving Weather for city number:322 | foumban
# Retrieving Weather for city number:323 | karkaralinsk
# City not found. Skipping
# Retrieving Weather for city number:323 | hirara
# Retrieving Weather for city number:324 | presidencia roque saenz pena
# Retrieving Weather for city number:325 | hayesville
# Retrieving Weather for city number:326 | lashio
# Retrieving Weather for city number:327 | abu dhabi
# Retrieving Weather for city number:328 | hollins
# Retrieving Weather for city number:329 | wajima
# Retrieving Weather for city number:330 | sur
# Retrieving Weather for city number:331 | maningrida
# Retrieving Weather for city number:332 | husavik
# Retrieving Weather for city number:333 | khatanga
# Retrieving Weather for city number:334 | biak
# Retrieving Weather for city number:335 | rostaq
# City not found. Skipping
# Retrieving Weather for city number:335 | bargal
# City not found. Skipping
# Retrieving Weather for city number:335 | sorvag
# City not found. Skipping
# Retrieving Weather for city number:335 | ryotsu
# Retrieving Weather for city number:336 | road town
# Retrieving Weather for city number:337 | madang
# Retrieving Weather for city number:338 | iiyama
# Retrieving Weather for city number:339 | yining
# Retrieving Weather for city number:340 | tiksi
# Retrieving Weather for city number:341 | port macquarie
# Retrieving Weather for city number:342 | vardo
# Retrieving Weather for city number:343 | xiongyue
# Retrieving Weather for city number:344 | marsh harbour
# Retrieving Weather for city number:345 | boa vista
# Retrieving Weather for city number:346 | manono
# Retrieving Weather for city number:347 | la asuncion
# Retrieving Weather for city number:348 | burica
# City not found. Skipping
# Retrieving Weather for city number:348 | shihezi
# Retrieving Weather for city number:349 | dhankuta
# Retrieving Weather for city number:350 | torbat-e jam
# Retrieving Weather for city number:351 | bucerias
# Retrieving Weather for city number:352 | lamar
# Retrieving Weather for city number:353 | severo-yeniseyskiy
# Retrieving Weather for city number:354 | wakkanai
# Retrieving Weather for city number:355 | sept-iles
# Retrieving Weather for city number:356 | miramar
# Retrieving Weather for city number:357 | gazanjyk
# Retrieving Weather for city number:358 | camacupa
# Retrieving Weather for city number:359 | deh rawud
# City not found. Skipping
# Retrieving Weather for city number:359 | komsomolskiy
# Retrieving Weather for city number:360 | oussouye
# Retrieving Weather for city number:361 | ust-kulom
# Retrieving Weather for city number:362 | bontang
# Retrieving Weather for city number:363 | namanga
# Retrieving Weather for city number:364 | nhulunbuy
# Retrieving Weather for city number:365 | aswan
# Retrieving Weather for city number:366 | dikson
# Retrieving Weather for city number:367 | pilao arcado
# City not found. Skipping
# Retrieving Weather for city number:367 | nortelandia
# Retrieving Weather for city number:368 | vrutky
# Retrieving Weather for city number:369 | molina
# Retrieving Weather for city number:370 | yulara
# Retrieving Weather for city number:371 | ust-nera
# Retrieving Weather for city number:372 | lodja
# Retrieving Weather for city number:373 | filingue
# Retrieving Weather for city number:374 | atar
# Retrieving Weather for city number:375 | shu
# Retrieving Weather for city number:376 | tecoanapa
# Retrieving Weather for city number:377 | mahibadhoo
# Retrieving Weather for city number:378 | omsukchan
# Retrieving Weather for city number:379 | bambous virieux
# Retrieving Weather for city number:380 | jarjis
# City not found. Skipping
# Retrieving Weather for city number:380 | kahului
# Retrieving Weather for city number:381 | russell
# Retrieving Weather for city number:382 | motzorongo
# Retrieving Weather for city number:383 | cabo san lucas
# Retrieving Weather for city number:384 | tilichiki
# Retrieving Weather for city number:385 | tamworth
# Retrieving Weather for city number:386 | harper
# Retrieving Weather for city number:387 | bendigo
# Retrieving Weather for city number:388 | ughelli
# Retrieving Weather for city number:389 | blovice
# Retrieving Weather for city number:390 | lunderskov
# Retrieving Weather for city number:391 | caravelas
# Retrieving Weather for city number:392 | baiyin
# Retrieving Weather for city number:393 | tortoli
# Retrieving Weather for city number:394 | aporawan
# City not found. Skipping
# Retrieving Weather for city number:394 | oktyabrskiy
# Retrieving Weather for city number:395 | yerbogachen
# Retrieving Weather for city number:396 | sioux lookout
# Retrieving Weather for city number:397 | san isidro
# Retrieving Weather for city number:398 | manuk mangkaw
# Retrieving Weather for city number:399 | gushikawa
# Retrieving Weather for city number:400 | pryyutivka
# Retrieving Weather for city number:401 | buariki
# City not found. Skipping
# Retrieving Weather for city number:401 | acapulco
# Retrieving Weather for city number:402 | sayyan
# Retrieving Weather for city number:403 | bloomington
# Retrieving Weather for city number:404 | zharkent
# Retrieving Weather for city number:405 | leh
# Retrieving Weather for city number:406 | zubova polyana
# Retrieving Weather for city number:407 | richards bay
# Retrieving Weather for city number:408 | yar-sale
# Retrieving Weather for city number:409 | praya
# Retrieving Weather for city number:410 | akdepe
# Retrieving Weather for city number:411 | oranjemund
# Retrieving Weather for city number:412 | truro
# Retrieving Weather for city number:413 | westport
# Retrieving Weather for city number:414 | skjervoy
# Retrieving Weather for city number:415 | barawe
# City not found. Skipping
# Retrieving Weather for city number:415 | killybegs
# Retrieving Weather for city number:416 | chipiona
# Retrieving Weather for city number:417 | vera cruz
# Retrieving Weather for city number:418 | saint-francois
# Retrieving Weather for city number:419 | tommot
# Retrieving Weather for city number:420 | samarai
# Retrieving Weather for city number:421 | sarny
# Retrieving Weather for city number:422 | bida
# Retrieving Weather for city number:423 | tangier
# Retrieving Weather for city number:424 | la ligua
# Retrieving Weather for city number:425 | erdemli
# Retrieving Weather for city number:426 | bredy
# Retrieving Weather for city number:427 | biggar
# Retrieving Weather for city number:428 | grand river south east
# City not found. Skipping
# Retrieving Weather for city number:428 | gravdal
# Retrieving Weather for city number:429 | villamontes
# Retrieving Weather for city number:430 | tartagal
# Retrieving Weather for city number:431 | den helder
# Retrieving Weather for city number:432 | eyrarbakki
# Retrieving Weather for city number:433 | korla
# Retrieving Weather for city number:434 | portland
# Retrieving Weather for city number:435 | lyuban
# Retrieving Weather for city number:436 | harrismith
# Retrieving Weather for city number:437 | coquimbo
# Retrieving Weather for city number:438 | jining
# Retrieving Weather for city number:439 | derzhavinsk
# Retrieving Weather for city number:440 | flinders
# Retrieving Weather for city number:441 | umm lajj
# Retrieving Weather for city number:442 | ilheus
# Retrieving Weather for city number:443 | bokspits
# City not found. Skipping
# Retrieving Weather for city number:443 | sabha
# Retrieving Weather for city number:444 | villazon
# Retrieving Weather for city number:445 | camapua
# Retrieving Weather for city number:446 | laguna
# Retrieving Weather for city number:447 | vila franca do campo
# Retrieving Weather for city number:448 | havre-saint-pierre
# Retrieving Weather for city number:449 | warmbad
# Retrieving Weather for city number:450 | east london
# Retrieving Weather for city number:451 | galgani
# City not found. Skipping
# Retrieving Weather for city number:451 | eyl
# Retrieving Weather for city number:452 | matangad
# Retrieving Weather for city number:453 | mehamn
# Retrieving Weather for city number:454 | boffa
# Retrieving Weather for city number:455 | fukue
# Retrieving Weather for city number:456 | havelock
# Retrieving Weather for city number:457 | nago
# Retrieving Weather for city number:458 | linhares
# Retrieving Weather for city number:459 | parrita
# Retrieving Weather for city number:460 | lata
# Retrieving Weather for city number:461 | boyabat
# Retrieving Weather for city number:462 | ankang
# Retrieving Weather for city number:463 | maarianhamina
# Retrieving Weather for city number:464 | grootfontein
# Retrieving Weather for city number:465 | cheremukhovo
# Retrieving Weather for city number:466 | daru
# Retrieving Weather for city number:467 | touros
# Retrieving Weather for city number:468 | idukki
# Retrieving Weather for city number:469 | satitoa
# City not found. Skipping
# Retrieving Weather for city number:469 | nador
# Retrieving Weather for city number:470 | yumen
# Retrieving Weather for city number:471 | pisco
# Retrieving Weather for city number:472 | sitka
# Retrieving Weather for city number:473 | narasannapeta
# Retrieving Weather for city number:474 | shelburne
# Retrieving Weather for city number:475 | jinchang
# Retrieving Weather for city number:476 | isangel
# Retrieving Weather for city number:477 | kozhva
# Retrieving Weather for city number:478 | kudahuvadhoo
# Retrieving Weather for city number:479 | leirvik
# Retrieving Weather for city number:480 | kazalinsk
# City not found. Skipping
# Retrieving Weather for city number:480 | mabaruma
# Retrieving Weather for city number:481 | kargasok
# Retrieving Weather for city number:482 | auki
# Retrieving Weather for city number:483 | kutum
# Retrieving Weather for city number:484 | gat
# Retrieving Weather for city number:485 | ulladulla
# Retrieving Weather for city number:486 | bilibino
# Retrieving Weather for city number:487 | liverpool
# Retrieving Weather for city number:488 | thayetmyo
# Retrieving Weather for city number:489 | walvis bay
# Retrieving Weather for city number:490 | vestmannaeyjar
# Retrieving Weather for city number:491 | rengali
# Retrieving Weather for city number:492 | san ramon de la nueva oran
# Retrieving Weather for city number:493 | kendari
# Retrieving Weather for city number:494 | solvychegodsk
# Retrieving Weather for city number:495 | boende
# Retrieving Weather for city number:496 | bandiagara
# Retrieving Weather for city number:497 | vanavara
# Retrieving Weather for city number:498 | khalkhal
# Retrieving Weather for city number:499 | iralaya
# Retrieving Weather for city number:500 | chipinge
# Retrieving Weather for city number:501 | khandyga
# Retrieving Weather for city number:502 | pochutla
# Retrieving Weather for city number:503 | kitui
# Retrieving Weather for city number:504 | matara
# Retrieving Weather for city number:505 | stantsiya gorchakovo
# City not found. Skipping
# Retrieving Weather for city number:505 | general roca
# Retrieving Weather for city number:506 | sao mateus
# Retrieving Weather for city number:507 | turtkul
# City not found. Skipping
# Retrieving Weather for city number:507 | temirtau
# Retrieving Weather for city number:508 | asau
# Retrieving Weather for city number:509 | newtownards
# Retrieving Weather for city number:510 | molchanovo
# Retrieving Weather for city number:511 | la ronge
# Retrieving Weather for city number:512 | mitsamiouli
# Retrieving Weather for city number:513 | zabid
# Retrieving Weather for city number:514 | kingsland
# Retrieving Weather for city number:515 | nemuro
# Retrieving Weather for city number:516 | pangkalanbuun
# Retrieving Weather for city number:517 | pangoa
# Retrieving Weather for city number:518 | aden
# Retrieving Weather for city number:519 | red bluff
# Retrieving Weather for city number:520 | mandera
# Retrieving Weather for city number:521 | kintampo
# Retrieving Weather for city number:522 | beian
# Retrieving Weather for city number:523 | itarema
# Retrieving Weather for city number:524 | cayenne
# Retrieving Weather for city number:525 | el tigre
# Retrieving Weather for city number:526 | tiarei
# Retrieving Weather for city number:527 | chalmette
# Retrieving Weather for city number:528 | ust-abakan
# Retrieving Weather for city number:529 | falealupo
# City not found. Skipping
# Retrieving Weather for city number:529 | zhanatas
# City not found. Skipping
# Retrieving Weather for city number:529 | pekan
# Retrieving Weather for city number:530 | hailar
# Retrieving Weather for city number:531 | minot
# Retrieving Weather for city number:532 | moskovskiy
# Retrieving Weather for city number:533 | miandrivazo
# Retrieving Weather for city number:534 | polunochnoye
# Retrieving Weather for city number:535 | acajutla
# Retrieving Weather for city number:536 | muzquiz
# City not found. Skipping
# Retrieving Weather for city number:536 | pechenga
# Retrieving Weather for city number:537 | belawan
# Retrieving Weather for city number:538 | meulaboh
# Retrieving Weather for city number:539 | chernyshevskiy
# Retrieving Weather for city number:540 | moron
# Retrieving Weather for city number:541 | changde
# Retrieving Weather for city number:542 | camabatela
# Retrieving Weather for city number:543 | ransang
# Retrieving Weather for city number:544 | sibu
# Retrieving Weather for city number:545 | shirokiy
# Retrieving Weather for city number:546 | kegayli
# City not found. Skipping
# Retrieving Weather for city number:546 | broken hill
# Retrieving Weather for city number:547 | collipulli
# Retrieving Weather for city number:548 | verkhniy baskunchak
# Retrieving Weather for city number:549 | kailua
# Retrieving Weather for city number:550 | camopi
# Retrieving Weather for city number:551 | sandwick
# Retrieving Weather for city number:552 | lasem
# Retrieving Weather for city number:553 | quelimane
# Retrieving Weather for city number:554 | kalispell
# Retrieving Weather for city number:555 | aguimes
# Retrieving Weather for city number:556 | burgeo
# Retrieving Weather for city number:557 | cap-aux-meules
# Retrieving Weather for city number:558 | san cristobal
# Retrieving Weather for city number:559 | adwa
# Retrieving Weather for city number:560 | barra do garcas
# Retrieving Weather for city number:561 | tazovskiy
# Retrieving Weather for city number:562 | ajdabiya
# Retrieving Weather for city number:563 | majene
# Retrieving Weather for city number:564 | waingapu
# Retrieving Weather for city number:565 | drexel heights
# Retrieving Weather for city number:566 | tautira
# Retrieving Weather for city number:567 | meyungs
# City not found. Skipping
# Retrieving Weather for city number:567 | braganca
# Retrieving Weather for city number:568 | haikou
# Retrieving Weather for city number:569 | viligili
# City not found. Skipping
# Retrieving Weather for city number:569 | tymovskoye
# Retrieving Weather for city number:570 | nishihara
# Retrieving Weather for city number:571 | nouakchott
# Retrieving Weather for city number:572 | orsha
# Retrieving Weather for city number:573 | nijar
# Retrieving Weather for city number:574 | contamana
# Retrieving Weather for city number:575 | torremolinos
# Retrieving Weather for city number:576 | ahipara
# Retrieving Weather for city number:577 | necochea
# Retrieving Weather for city number:578 | carutapera

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("Results/Cities.csv", encoding="utf-8", index=False)

# %%
cities_df["Date"]=cities_df["Date"].astype(int)
cities_df.head()
# Out:
#    City Number          City  Cloudiness        Date  Humidity    Lat     Lng  \
# 0          1.0        Hobart        90.0  1586884824      82.0 -42.88  147.33
# 1          2.0  Punta Arenas        75.0  1586884830      62.0 -53.15  -70.92
# 2          3.0      Kurumkan        88.0  1586884831      54.0  54.30  110.30
# 3          4.0      Temerloh        86.0  1586884831      88.0   3.45  102.42
# 4          5.0        Castro        89.0  1586884831      53.0 -24.79  -50.01
#
#    Max Temp  Wind Speed
# 0     15.56        3.60
# 1     12.00        8.70
# 2      3.01        1.78
# 3     24.01        0.52
# 4     20.48        3.23

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#Convert Unix timestamp to datetime (to use it in fig title)
from datetime import datetime
current_time=cities_df["Date"][len(cities_df["Date"])-1]
time_utc=time.strftime("%D %H:%M", time.localtime(current_time))
time_utc
# Out:
# '04/14/20 12:22'

# %% [markdown]
# #### Latitude vs. Temperature Plot
# * Create a scatter plot to showcase the relationship between the latitude of a city and the maximum temperature registered (in Fahrenheit)

# %%
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Max Temperature (C)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'City Latitude vs Max Temperature ({time_utc})', fontsize=12, fontweight="bold")
plt.savefig("Results/temp_vs_lat.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot
# * Create a scatter plot to showcase the relationship between the latitude of a city and the humidity registered (in %)

# %%
#Create a scatter plot to showcase the relationship between the latitude of a city and the maximum temperature
#registered

plt.scatter(cities_df["Lat"], cities_df["Humidity"], marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'City Latitude vs Humidity ({time_utc})', fontsize=12, fontweight="bold")
plt.savefig("Results/humidity_vs_lat.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot
# * Create a scatter plot to showcase the relationship between the latitude of a city and the cloudiness registered (in %)

# %%
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'City Latitude vs Cloudiness ({time_utc})', fontsize=12, fontweight="bold")
plt.savefig("Results/cloudiness_vs_lat.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
# * Create a scatter plot to showcase the relationship between the latitude of a city and the wind speed registered (in m/s)

# %%
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Wind Speed (m/s)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'City Latitude vs Wind Speed ({time_utc})', fontsize=12, fontweight="bold")
plt.savefig("Results/wind_speed_vs_lat.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr)=linregress(x_values, y_values)
    slope, intercept, rvalue, pvalue, stderr
    regress_values= x_values * slope + intercept
    line_eq= "y=" + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(f'The correlation coefficient (r) is: {rvalue}')
    plt.plot(x_values, regress_values, "r-")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df=cities_df.loc[cities_df["Lat"] >= 0]
south_df=cities_df.loc[cities_df["Lat"] < 0]
south_df.head()
# Out:
#    City Number          City  Cloudiness        Date  Humidity    Lat     Lng  \
# 0          1.0        Hobart        90.0  1586884824      82.0 -42.88  147.33
# 1          2.0  Punta Arenas        75.0  1586884830      62.0 -53.15  -70.92
# 4          5.0        Castro        89.0  1586884831      53.0 -24.79  -50.01
# 6          7.0  Saint-Joseph        40.0  1586884831      78.0 -21.37   55.62
# 7          8.0    Bell Ville        43.0  1586884832      40.0 -32.63  -62.69
#
#    Max Temp  Wind Speed
# 0     15.56        3.60
# 1     12.00        8.70
# 4     20.48        3.23
# 6     25.00        2.10
# 7     22.78        0.89

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the maximum temperature registered (in Fahrenheit), focusing on the Northen Hemisphere.
# * The correlation coefficient is -0.89, showing a strong negative correlation between latitude and temperature (i.e. if latitude increases, temperature decreases)

# %%
x_values= north_df["Lat"]
y_values= north_df["Max Temp"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Max Temperature (C)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Northern Hemisphere: City Latitude vs Max Temperature \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (0,-20), fontsize=15, color="red")

plt.savefig("Results/temp_vs_lat_regression_north.png")
# Out:
# The correlation coefficient (r) is: -0.8883074466844999

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the maximum temperature registered (in Fahrenheit), focusing on the Southern Hemisphere.
# * The correlation coefficient is -0.72, showing a strong positive correlation between latitude and temperature (i.e. if latitude increases (or become less negative), temperature increases)

# %%
x_values= south_df["Lat"]
y_values= south_df["Max Temp"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Max Temperature (C)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Southern Hemisphere: City Latitude vs Max Temperature \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (-30,5), fontsize=15, color="red")

plt.savefig("Results/temp_vs_lat_regression_south.png")
# Out:
# The correlation coefficient (r) is: 0.7183196930342979

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the humidity registered (in %), focusing on the Northen Hemisphere.
# * The correlation coefficient is 0.34, showing a weak positive correlation between latitude and humidity (i.e. if latitude increases, humidity slightly increases)

# %%
x_values= north_df["Lat"]
y_values= north_df["Humidity"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Northern Hemisphere: City Latitude vs Humidity \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (55,20), fontsize=12, color="red")

plt.savefig("Results/humidity_vs_lat_regression_north.png")
# Out:
# The correlation coefficient (r) is: 0.3468690800646733

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the humidity registered (in %), focusing on the Southern Hemisphere.
# * The correlation coefficient is 0.2, showing none, or very weak positive correlation between latitude and humidity

# %%
x_values= south_df["Lat"]
y_values= south_df["Humidity"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Southern Hemisphere: City Latitude vs Humidity \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (-55,20), fontsize=12, color="red")

plt.savefig("Results/humidity_vs_lat_regression_south.png")
# Out:
# The correlation coefficient (r) is: 0.19888540390082315

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the cloudiness registered (in %), focusing on the Northern Hemisphere.
# * The correlation coefficient is 0.26, showing none, or very weak positive correlation between latitude and cloudiness

# %%
x_values= north_df["Lat"]
y_values= north_df["Cloudiness"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Northern Hemisphere: City Latitude vs Cloudiness \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (55,20), fontsize=12, color="red")

plt.savefig("Results/cloudiness_vs_lat_regression_north.png")
# Out:
# The correlation coefficient (r) is: 0.2587215172957024

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the cloudiness registered (in %), focusing on the Southern Hemisphere.
# * The correlation coefficient is 0.19, showing none, or very weak positive correlation between latitude and cloudiness

# %%
x_values= south_df["Lat"]
y_values= south_df["Cloudiness"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Southern Hemisphere: City Latitude vs Cloudiness \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (-55,30), fontsize=12, color="red")

plt.savefig("Results/cloudiness_vs_lat_regression_south.png")
# Out:
# The correlation coefficient (r) is: 0.1901604568202059

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the wind speed registered (in m/s), focusing on the Northern Hemisphere.
# * The correlation coefficient is 0.13, showing none, or very weak positive correlation between latitude and wind speed

# %%
x_values= north_df["Lat"]
y_values= north_df["Wind Speed"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Wind Speed (m/s)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Northern Hemisphere: City Latitude vs Wind Speed \n ({time_utc})', fontsize=12, fontweight="bold")

north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (5,13), fontsize=12, color="red")

plt.savefig("Results/wind_vs_lat_regression_north.png")
# Out:
# The correlation coefficient (r) is: 0.13080286422555243

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# * The scatter plot and linear regression showcase the relationship between the latitude of a city and the wind speed registered (in m/s), focusing on the Southern Hemisphere.
# * The correlation coefficient is -0.25, showing none, or very weak negative correlation between latitude and wind speed

# %%
x_values= south_df["Lat"]
y_values= south_df["Wind Speed"]

plt.scatter(x_values, y_values, marker="o", c= "blue", alpha=0.75, edgecolors="black")
plt.ylabel("Wind Speed (m/s)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.title(f'Southern Hemisphere: City Latitude vs Wind Speed \n ({time_utc})', fontsize=12, fontweight="bold")


north_plot=plot_regression(x_values, y_values)
plt.annotate(line_eq, (-55,10), fontsize=12, color="red")

plt.savefig("Results/wind_vs_lat_regression_south.png")
# Out:
# The correlation coefficient (r) is: -0.25163949778068806
